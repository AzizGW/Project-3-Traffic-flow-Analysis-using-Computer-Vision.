# %%
import torch
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision import datasets, transforms
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
import os
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import cv2
import numpy as np
from torchvision.transforms.functional import to_pil_image
import seaborn as sns

# %%
class TrafficDataset(Dataset):
    def __init__(self, directory, transform=None):
        self.directory = directory
        self.transform = transform
        self.images = [f for f in os.listdir(directory) if f.endswith('.jpg')]
        self.images.sort()  # sorted by time

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = os.path.join(self.directory, self.images[idx])
        image = read_image(img_name)
        timestamp = pd.to_datetime(self.images[idx].split('.')[0], format='%Y-%m-%dT%H-%M-%S')
        if self.transform:
            image = self.transform(image)
        timestamp = pd.to_datetime(self.images[idx].split('.')[0], format='%Y-%m-%dT%H-%M-%S')
        # Decrease the time by three hours
        timestamp -= pd.Timedelta(hours=3)
        timestamp = timestamp.strftime('%Y-%m-%d %H:%M:%S')  # Convert to string
        print(timestamp)
        return image, timestamp

dataset = TrafficDataset('./test', transform=transforms.Compose([
    transforms.Resize((640, 640)),
    transforms.ConvertImageDtype(torch.float)
]))
dataloader = DataLoader(dataset, batch_size=8, shuffle=False)

# %%
COCO_INSTANCE_CATEGORY_NAMES = [
    None,  
    'person', 'bicycle', 'car', 'motorcycle', 'airplane',
    'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', None,  
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', None, None,  
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
    'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard',
    'tennis racket', 'bottle', None, 'wine glass', 'cup', 'fork', 'knife', 'spoon',
    'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog',
    'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
    None, 'dining table', None, None, 'toilet', None, 'tv', 'laptop', 'mouse', 'remote',
    'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', None,
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# %%
# pre-trained Faster R-CNN model
model = fasterrcnn_resnet50_fpn(pretrain=True)

device = torch.device("mps" if torch.cuda.is_available() else "cpu")# mps for Apple M1/M2
model.to(device)
model.eval()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#   )
# )

# %%
# object categories 
interested_objects = ['car', 'bus','person','truck']
object_counts = defaultdict(list)

print("Starting processing...")
borderline_y = 240  # the y-coordinate of the borderline

for batch_idx, (images, timestamps) in enumerate(dataloader):
    print(f"Processing batch {batch_idx+1}/{len(dataloader)}")
    images = list(image.to(device) for image in images)
    
    with torch.no_grad():
        outputs = model(images)
    
    print(f"Batch {batch_idx+1}: Model has outputted results.")
    
    confidence_threshold = 0.8 
    
    for i, output in enumerate(outputs):
        count = {obj: 0 for obj in interested_objects}
        for label, box, score in zip(output['labels'], output['boxes'], output['scores']):
            if score > confidence_threshold:
                if label.item() < len(COCO_INSTANCE_CATEGORY_NAMES):
                    label_name = COCO_INSTANCE_CATEGORY_NAMES[label.item()]
                    if label_name in interested_objects:
                        x1, y1, x2, y2 = box.int().tolist()
                        if y1 > borderline_y or y2 > borderline_y:
                            count[label_name] += 1

        
        # the counts for the current image
        print(f"Image {i+1} in batch {batch_idx+1}: Object counts - {count}")
        
        for obj in interested_objects:
            object_counts[obj].append((timestamps[i], count[obj]))
            
    print(f"Completed processing batch {batch_idx+1}.")
    
print("Completed all processing.")

#print a summary of counts for debugging
print("Summary of object counts:")
for obj, counts in object_counts.items():
    print(f"{obj}: Total count over all images - {sum([count for _, count in counts])}")
# Out:
# Starting processing...
# 2021-05-01 00:01:05
# 2021-05-01 00:02:47
# 2021-05-01 00:04:28
# 2021-05-01 00:06:10
# 2021-05-01 00:07:51
# 2021-05-01 00:09:33
# /Users/abdulazizalyahya/.pyenv/versions/3.8.18/lib/python3.8/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 2021-05-01 00:11:14
# 2021-05-01 00:12:56
# Processing batch 1/701
# Batch 1: Model has outputted results.
# Image 1 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 1: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 1: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 1.
# 2021-05-01 00:14:37
# 2021-05-01 00:16:17
# 2021-05-01 00:17:58
# 2021-05-01 00:19:40
# 2021-05-01 00:21:21
# 2021-05-01 00:23:02
# 2021-05-01 00:24:44
# 2021-05-01 00:26:26
# Processing batch 2/701
# Batch 2: Model has outputted results.
# Image 1 in batch 2: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 2 in batch 2: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 2: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 2: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 2: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 2: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 2: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 2: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 2.
# 2021-05-01 00:28:08
# 2021-05-01 00:29:48
# 2021-05-01 00:31:30
# 2021-05-01 00:33:10
# 2021-05-01 00:34:53
# 2021-05-01 00:36:35
# 2021-05-01 00:38:17
# 2021-05-01 00:39:59
# Processing batch 3/701
# Batch 3: Model has outputted results.
# Image 1 in batch 3: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 3: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 3: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 3: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 3: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 3: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 3: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 3: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 3.
# 2021-05-01 00:41:39
# 2021-05-01 00:43:22
# 2021-05-01 00:45:03
# 2021-05-01 00:46:45
# 2021-05-01 00:48:26
# 2021-05-01 00:50:06
# 2021-05-01 00:51:49
# 2021-05-01 00:53:32
# Processing batch 4/701
# Batch 4: Model has outputted results.
# Image 1 in batch 4: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 4: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 4: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 4: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 4: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 6 in batch 4: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 4: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 4: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 4.
# 2021-05-01 00:55:13
# 2021-05-01 00:56:55
# 2021-05-01 00:58:37
# 2021-05-01 01:00:18
# 2021-05-01 01:01:58
# 2021-05-01 01:03:39
# 2021-05-01 01:05:21
# 2021-05-01 01:07:02
# Processing batch 5/701
# Batch 5: Model has outputted results.
# Image 1 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 5: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 5: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 5.
# 2021-05-01 01:08:43
# 2021-05-01 01:10:24
# 2021-05-01 01:12:06
# 2021-05-01 01:13:47
# 2021-05-01 01:15:28
# 2021-05-01 01:17:08
# 2021-05-01 01:18:49
# 2021-05-01 01:20:30
# Processing batch 6/701
# Batch 6: Model has outputted results.
# Image 1 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 6: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Completed processing batch 6.
# 2021-05-01 01:22:11
# 2021-05-01 01:23:52
# 2021-05-01 01:25:33
# 2021-05-01 01:27:16
# 2021-05-01 01:28:58
# 2021-05-01 01:30:39
# 2021-05-01 01:32:21
# 2021-05-01 01:34:03
# Processing batch 7/701
# Batch 7: Model has outputted results.
# Image 1 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 5 in batch 7: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 6 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 7: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 7.
# 2021-05-01 01:35:46
# 2021-05-01 01:37:31
# 2021-05-01 01:39:15
# 2021-05-01 01:40:56
# 2021-05-01 01:42:37
# 2021-05-01 01:44:19
# 2021-05-01 01:46:01
# 2021-05-01 01:47:42
# Processing batch 8/701
# Batch 8: Model has outputted results.
# Image 1 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 2 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 3 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 8: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 8: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 8.
# 2021-05-01 01:49:24
# 2021-05-01 01:59:31
# 2021-05-01 02:00:15
# 2021-05-01 02:01:19
# 2021-05-01 02:03:00
# 2021-05-01 02:04:42
# 2021-05-01 02:06:23
# 2021-05-01 02:07:17
# Processing batch 9/701
# Batch 9: Model has outputted results.
# Image 1 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 9: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 9: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 9.
# 2021-05-01 02:08:57
# 2021-05-01 02:11:09
# 2021-05-01 02:13:01
# 2021-05-01 02:14:42
# 2021-05-01 02:16:24
# 2021-05-01 02:18:08
# 2021-05-01 02:19:49
# 2021-05-01 02:21:30
# Processing batch 10/701
# Batch 10: Model has outputted results.
# Image 1 in batch 10: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 10: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 10: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 10: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 10: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 10: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 10: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 10: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 10.
# 2021-05-01 02:23:12
# 2021-05-01 02:24:54
# 2021-05-01 02:26:34
# 2021-05-01 02:28:16
# 2021-05-01 02:29:58
# 2021-05-01 02:31:40
# 2021-05-01 02:33:20
# 2021-05-01 02:35:04
# Processing batch 11/701
# Batch 11: Model has outputted results.
# Image 1 in batch 11: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 11: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 11: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 11: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 5 in batch 11: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 11: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 7 in batch 11: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 11: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 11.
# 2021-05-01 02:36:50
# 2021-05-01 02:38:36
# 2021-05-01 02:40:21
# 2021-05-01 02:42:06
# 2021-05-01 02:43:49
# 2021-05-01 02:45:33
# 2021-05-01 02:47:18
# 2021-05-01 02:49:01
# Processing batch 12/701
# Batch 12: Model has outputted results.
# Image 1 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 12: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 12.
# 2021-05-01 02:50:44
# 2021-05-01 02:52:27
# 2021-05-01 02:54:09
# 2021-05-01 02:55:51
# 2021-05-01 02:57:34
# 2021-05-01 02:59:14
# 2021-05-01 03:00:54
# 2021-05-01 03:02:35
# Processing batch 13/701
# Batch 13: Model has outputted results.
# Image 1 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 4, 'truck': 0}
# Image 5 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 13: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 13.
# 2021-05-01 03:04:16
# 2021-05-01 03:05:57
# 2021-05-01 03:07:38
# 2021-05-01 03:09:20
# 2021-05-01 03:11:01
# 2021-05-01 03:12:42
# 2021-05-01 03:14:22
# 2021-05-01 03:16:03
# Processing batch 14/701
# Batch 14: Model has outputted results.
# Image 1 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 14: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 14.
# 2021-05-01 03:17:45
# 2021-05-01 03:19:27
# 2021-05-01 03:21:11
# 2021-05-01 03:22:55
# 2021-05-01 03:24:38
# 2021-05-01 03:26:21
# 2021-05-01 03:28:04
# 2021-05-01 03:29:47
# Processing batch 15/701
# Batch 15: Model has outputted results.
# Image 1 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 15: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 15.
# 2021-05-01 03:31:32
# 2021-05-01 03:33:17
# 2021-05-01 03:35:01
# 2021-05-01 03:36:47
# 2021-05-01 03:38:32
# 2021-05-01 03:40:17
# 2021-05-01 03:42:02
# 2021-05-01 03:43:46
# Processing batch 16/701
# Batch 16: Model has outputted results.
# Image 1 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 16: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 16.
# 2021-05-01 03:45:30
# 2021-05-01 03:47:15
# 2021-05-01 03:49:06
# 2021-05-01 03:51:01
# 2021-05-01 03:52:54
# 2021-05-01 03:54:48
# 2021-05-01 03:56:35
# 2021-05-01 03:58:25
# Processing batch 17/701
# Batch 17: Model has outputted results.
# Image 1 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 4 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 1}
# Image 7 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 17: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 17.
# 2021-05-01 04:00:13
# 2021-05-01 04:02:01
# 2021-05-01 04:03:47
# 2021-05-01 04:05:32
# 2021-05-01 04:07:17
# 2021-05-01 04:09:02
# 2021-05-01 04:10:48
# 2021-05-01 04:12:31
# Processing batch 18/701
# Batch 18: Model has outputted results.
# Image 1 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 18: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 18.
# 2021-05-01 04:14:19
# 2021-05-01 04:16:07
# 2021-05-01 04:17:50
# 2021-05-01 04:19:34
# 2021-05-01 04:21:18
# 2021-05-01 04:23:03
# 2021-05-01 04:24:48
# 2021-05-01 04:26:33
# Processing batch 19/701
# Batch 19: Model has outputted results.
# Image 1 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 19: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 19.
# 2021-05-01 04:28:19
# 2021-05-01 04:30:03
# 2021-05-01 04:31:49
# 2021-05-01 04:33:33
# 2021-05-01 04:35:18
# 2021-05-01 04:37:05
# 2021-05-01 04:38:55
# 2021-05-01 04:40:55
# Processing batch 20/701
# Batch 20: Model has outputted results.
# Image 1 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 20: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 20.
# 2021-05-01 04:42:48
# 2021-05-01 04:44:38
# 2021-05-01 04:46:29
# 2021-05-01 04:48:18
# 2021-05-01 04:50:08
# 2021-05-01 04:51:57
# 2021-05-01 04:53:47
# 2021-05-01 04:55:37
# Processing batch 21/701
# Batch 21: Model has outputted results.
# Image 1 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 3, 'truck': 0}
# Image 3 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 21: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 21.
# 2021-05-01 04:57:34
# 2021-05-01 04:59:27
# 2021-05-01 05:01:20
# 2021-05-01 05:03:08
# 2021-05-01 05:04:55
# 2021-05-01 05:06:39
# 2021-05-01 05:08:23
# 2021-05-01 05:10:08
# Processing batch 22/701
# Batch 22: Model has outputted results.
# Image 1 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 22: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 22.
# 2021-05-01 05:11:53
# 2021-05-01 05:13:39
# 2021-05-01 05:15:23
# 2021-05-01 05:17:07
# 2021-05-01 05:18:51
# 2021-05-01 05:20:35
# 2021-05-01 05:22:20
# 2021-05-01 05:24:09
# Processing batch 23/701
# Batch 23: Model has outputted results.
# Image 1 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 23: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 23.
# 2021-05-01 05:25:55
# 2021-05-01 05:27:41
# 2021-05-01 05:29:27
# 2021-05-01 05:31:13
# 2021-05-01 05:32:59
# 2021-05-01 05:34:42
# 2021-05-01 05:36:28
# 2021-05-01 05:38:16
# Processing batch 24/701
# Batch 24: Model has outputted results.
# Image 1 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 24: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 24.
# 2021-05-01 05:40:06
# 2021-05-01 05:41:53
# 2021-05-01 05:43:42
# 2021-05-01 05:45:31
# 2021-05-01 05:47:25
# 2021-05-01 05:49:18
# 2021-05-01 05:51:06
# 2021-05-01 05:52:50
# Processing batch 25/701
# Batch 25: Model has outputted results.
# Image 1 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 25: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 25.
# 2021-05-01 05:54:33
# 2021-05-01 05:56:18
# 2021-05-01 05:58:02
# 2021-05-01 05:59:47
# 2021-05-01 06:01:32
# 2021-05-01 06:03:16
# 2021-05-01 06:05:00
# 2021-05-01 06:06:43
# Processing batch 26/701
# Batch 26: Model has outputted results.
# Image 1 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 26: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 26.
# 2021-05-01 06:08:26
# 2021-05-01 06:10:08
# 2021-05-01 06:11:50
# 2021-05-01 06:13:31
# 2021-05-01 06:15:13
# 2021-05-01 06:16:57
# 2021-05-01 06:18:43
# 2021-05-01 06:20:27
# Processing batch 27/701
# Batch 27: Model has outputted results.
# Image 1 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 27: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 27: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 27.
# 2021-05-01 06:22:09
# 2021-05-01 06:23:53
# 2021-05-01 06:25:40
# 2021-05-01 06:27:25
# 2021-05-01 06:29:09
# 2021-05-01 06:30:54
# 2021-05-01 06:32:44
# 2021-05-01 06:34:35
# Processing batch 28/701
# Batch 28: Model has outputted results.
# Image 1 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 28: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 28.
# 2021-05-01 06:36:24
# 2021-05-01 06:38:11
# 2021-05-01 06:39:56
# 2021-05-01 06:41:41
# 2021-05-01 06:43:26
# 2021-05-01 06:45:13
# 2021-05-01 06:47:02
# 2021-05-01 06:48:44
# Processing batch 29/701
# Batch 29: Model has outputted results.
# Image 1 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 2 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 29: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 29.
# 2021-05-01 06:50:28
# 2021-05-01 06:52:12
# 2021-05-01 06:53:57
# 2021-05-01 06:55:40
# 2021-05-01 06:57:23
# 2021-05-01 06:59:06
# 2021-05-01 07:00:49
# 2021-05-01 07:02:32
# Processing batch 30/701
# Batch 30: Model has outputted results.
# Image 1 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 30: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 30.
# 2021-05-01 07:04:16
# 2021-05-01 07:05:59
# 2021-05-01 07:07:43
# 2021-05-01 07:09:28
# 2021-05-01 07:11:13
# 2021-05-01 07:12:59
# 2021-05-01 07:14:47
# 2021-05-01 07:16:31
# Processing batch 31/701
# Batch 31: Model has outputted results.
# Image 1 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 31: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 6 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 31: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 31.
# 2021-05-01 07:18:17
# 2021-05-01 07:20:04
# 2021-05-01 07:21:50
# 2021-05-01 07:23:32
# 2021-05-01 07:25:18
# 2021-05-01 07:27:02
# 2021-05-01 07:28:48
# 2021-05-01 07:30:34
# Processing batch 32/701
# Batch 32: Model has outputted results.
# Image 1 in batch 32: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 32: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 32: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 32: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 32: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 1}
# Image 6 in batch 32: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 32: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 32: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 32.
# 2021-05-01 07:32:20
# 2021-05-01 07:34:04
# 2021-05-01 07:35:45
# 2021-05-01 07:37:27
# 2021-05-01 07:39:07
# 2021-05-01 07:40:47
# 2021-05-01 07:42:28
# 2021-05-01 07:44:08
# Processing batch 33/701
# Batch 33: Model has outputted results.
# Image 1 in batch 33: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 33: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 33: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 33: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 33: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 33: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 33: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 33: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 33.
# 2021-05-01 07:45:49
# 2021-05-01 07:47:30
# 2021-05-01 07:49:11
# 2021-05-01 07:50:52
# 2021-05-01 07:52:33
# 2021-05-01 07:54:14
# 2021-05-01 07:55:55
# 2021-05-01 07:57:36
# Processing batch 34/701
# Batch 34: Model has outputted results.
# Image 1 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 34: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 34: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 34.
# 2021-05-01 07:59:21
# 2021-05-01 08:01:07
# 2021-05-01 08:02:58
# 2021-05-01 08:04:46
# 2021-05-01 08:06:32
# 2021-05-01 08:08:16
# 2021-05-01 08:09:59
# 2021-05-01 08:11:43
# Processing batch 35/701
# Batch 35: Model has outputted results.
# Image 1 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 35: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 35: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 35.
# 2021-05-01 08:13:26
# 2021-05-01 08:15:11
# 2021-05-01 08:16:55
# 2021-05-01 08:18:37
# 2021-05-01 08:20:20
# 2021-05-01 08:22:03
# 2021-05-01 08:23:46
# 2021-05-01 08:25:30
# Processing batch 36/701
# Batch 36: Model has outputted results.
# Image 1 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 7 in batch 36: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 36: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 36.
# 2021-05-01 08:27:13
# 2021-05-01 08:28:57
# 2021-05-01 08:30:42
# 2021-05-01 08:32:26
# 2021-05-01 08:34:09
# 2021-05-01 08:35:53
# 2021-05-01 08:37:44
# 2021-05-01 08:39:42
# Processing batch 37/701
# Batch 37: Model has outputted results.
# Image 1 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 37: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 37.
# 2021-05-01 08:41:32
# 2021-05-01 08:43:19
# 2021-05-01 08:45:05
# 2021-05-01 08:46:50
# 2021-05-01 08:48:33
# 2021-05-01 08:50:16
# 2021-05-01 08:52:00
# 2021-05-01 08:53:43
# Processing batch 38/701
# Batch 38: Model has outputted results.
# Image 1 in batch 38: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 38: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 38: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 1}
# Image 4 in batch 38: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 38: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 38: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 38: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 38: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 38.
# 2021-05-01 08:55:26
# 2021-05-01 08:57:10
# 2021-05-01 08:58:51
# 2021-05-01 09:00:32
# 2021-05-01 09:02:13
# 2021-05-01 09:03:56
# 2021-05-01 09:05:37
# 2021-05-01 09:07:17
# Processing batch 39/701
# Batch 39: Model has outputted results.
# Image 1 in batch 39: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 39: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 39.
# 2021-05-01 09:08:58
# 2021-05-01 09:10:38
# 2021-05-01 09:12:19
# 2021-05-01 09:14:00
# 2021-05-01 09:15:40
# 2021-05-01 09:17:21
# 2021-05-01 09:19:01
# 2021-05-01 09:20:42
# Processing batch 40/701
# Batch 40: Model has outputted results.
# Image 1 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 40: Object counts - {'car': 1, 'bus': 1, 'person': 0, 'truck': 0}
# Image 4 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 40: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 40.
# 2021-05-01 09:22:22
# 2021-05-01 09:24:03
# 2021-05-01 09:25:44
# 2021-05-01 09:27:24
# 2021-05-01 09:29:05
# 2021-05-01 09:30:47
# 2021-05-01 09:32:27
# 2021-05-01 09:34:09
# Processing batch 41/701
# Batch 41: Model has outputted results.
# Image 1 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 41: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Completed processing batch 41.
# 2021-05-01 09:35:50
# 2021-05-01 09:37:29
# 2021-05-01 09:39:10
# 2021-05-01 09:40:50
# 2021-05-01 09:42:31
# 2021-05-01 09:44:11
# 2021-05-01 09:45:51
# 2021-05-01 09:47:32
# Processing batch 42/701
# Batch 42: Model has outputted results.
# Image 1 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 42: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 42: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 42.
# 2021-05-01 09:49:13
# 2021-05-01 09:50:53
# 2021-05-01 09:52:36
# 2021-05-01 09:54:19
# 2021-05-01 09:56:02
# 2021-05-01 09:57:45
# 2021-05-01 09:59:26
# 2021-05-01 10:01:09
# Processing batch 43/701
# Batch 43: Model has outputted results.
# Image 1 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 43: Object counts - {'car': 1, 'bus': 0, 'person': 2, 'truck': 0}
# Image 3 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 5 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 8 in batch 43: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Completed processing batch 43.
# 2021-05-01 10:02:51
# 2021-05-01 10:04:33
# 2021-05-01 10:06:16
# 2021-05-01 10:08:01
# 2021-05-01 10:09:45
# 2021-05-01 10:11:30
# 2021-05-01 10:13:12
# 2021-05-01 10:14:55
# Processing batch 44/701
# Batch 44: Model has outputted results.
# Image 1 in batch 44: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Image 2 in batch 44: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 3 in batch 44: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 4 in batch 44: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 5 in batch 44: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 44: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 44: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 44: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 44.
# 2021-05-01 10:16:37
# 2021-05-01 10:18:20
# 2021-05-01 10:20:03
# 2021-05-01 10:21:47
# 2021-05-01 10:23:31
# 2021-05-01 10:25:16
# 2021-05-01 10:27:04
# 2021-05-01 10:28:53
# Processing batch 45/701
# Batch 45: Model has outputted results.
# Image 1 in batch 45: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 1}
# Image 2 in batch 45: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 45: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 45: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 45: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 6 in batch 45: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 7 in batch 45: Object counts - {'car': 0, 'bus': 0, 'person': 3, 'truck': 0}
# Image 8 in batch 45: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 45.
# 2021-05-01 10:30:48
# 2021-05-01 10:32:42
# 2021-05-01 10:34:33
# 2021-05-01 10:36:24
# 2021-05-01 10:38:11
# 2021-05-01 10:40:00
# 2021-05-01 10:41:47
# 2021-05-01 10:43:36
# Processing batch 46/701
# Batch 46: Model has outputted results.
# Image 1 in batch 46: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 46: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 46: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 46: Object counts - {'car': 0, 'bus': 1, 'person': 1, 'truck': 0}
# Image 5 in batch 46: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 1}
# Image 6 in batch 46: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 46: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 46: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 46.
# 2021-05-01 10:45:22
# 2021-05-01 10:47:09
# 2021-05-01 10:48:58
# 2021-05-01 10:50:52
# 2021-05-01 10:52:49
# 2021-05-01 10:54:39
# 2021-05-01 10:56:28
# 2021-05-01 10:58:15
# Processing batch 47/701
# Batch 47: Model has outputted results.
# Image 1 in batch 47: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 47: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 47: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 47: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 47: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 47: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 47: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 47: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 47.
# 2021-05-01 11:00:03
# 2021-05-01 11:01:47
# 2021-05-01 11:03:30
# 2021-05-01 11:05:13
# 2021-05-01 11:06:56
# 2021-05-01 11:08:39
# 2021-05-01 11:10:23
# 2021-05-01 11:12:05
# Processing batch 48/701
# Batch 48: Model has outputted results.
# Image 1 in batch 48: Object counts - {'car': 0, 'bus': 1, 'person': 2, 'truck': 0}
# Image 2 in batch 48: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 48: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 48: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 48: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 48: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 1}
# Image 7 in batch 48: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 48: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 48.
# 2021-05-01 11:13:50
# 2021-05-01 11:15:35
# 2021-05-01 11:16:23
# 2021-05-01 11:18:04
# 2021-05-01 11:19:44
# 2021-05-01 11:21:26
# 2021-05-01 11:23:05
# 2021-05-01 11:24:45
# Processing batch 49/701
# Batch 49: Model has outputted results.
# Image 1 in batch 49: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 2 in batch 49: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 3 in batch 49: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 49: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 49: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 49: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 49: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 8 in batch 49: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 49.
# 2021-05-01 11:26:25
# 2021-05-01 11:28:06
# 2021-05-01 11:29:46
# 2021-05-01 11:31:25
# 2021-05-01 11:33:05
# 2021-05-01 11:34:45
# 2021-05-01 11:36:26
# 2021-05-01 11:38:05
# Processing batch 50/701
# Batch 50: Model has outputted results.
# Image 1 in batch 50: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 50: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 50: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 50: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 50: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 6 in batch 50: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 50: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 8 in batch 50: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 50.
# 2021-05-01 11:39:45
# 2021-05-01 11:41:25
# 2021-05-01 11:43:05
# 2021-05-01 11:44:45
# 2021-05-01 11:46:25
# 2021-05-01 11:48:06
# 2021-05-01 11:49:46
# 2021-05-01 11:51:27
# Processing batch 51/701
# Batch 51: Model has outputted results.
# Image 1 in batch 51: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 51: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 1}
# Image 3 in batch 51: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 51: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 51: Object counts - {'car': 4, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 51: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 51: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 51: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 51.
# 2021-05-01 11:53:05
# 2021-05-01 11:54:46
# 2021-05-01 11:56:27
# 2021-05-01 11:58:08
# 2021-05-01 11:59:47
# 2021-05-01 12:01:30
# 2021-05-01 12:03:07
# 2021-05-01 12:04:47
# Processing batch 52/701
# Batch 52: Model has outputted results.
# Image 1 in batch 52: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 2 in batch 52: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 52: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# ...
# Completed processing batch 684.
# 2021-05-07 16:46:03
# 2021-05-07 16:47:48
# 2021-05-07 16:49:32
# 2021-05-07 16:51:16
# 2021-05-07 16:53:01
# 2021-05-07 16:54:47
# 2021-05-07 16:56:37
# 2021-05-07 16:58:34
# Processing batch 685/701
# Batch 685: Model has outputted results.
# Image 1 in batch 685: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 685: Object counts - {'car': 4, 'bus': 0, 'person': 1, 'truck': 1}
# Image 3 in batch 685: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 4 in batch 685: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 5 in batch 685: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 6 in batch 685: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 7 in batch 685: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Image 8 in batch 685: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Completed processing batch 685.
# 2021-05-07 17:00:23
# 2021-05-07 17:02:16
# 2021-05-07 17:04:06
# 2021-05-07 17:05:57
# 2021-05-07 17:07:47
# 2021-05-07 17:09:35
# 2021-05-07 17:11:25
# 2021-05-07 17:13:15
# Processing batch 686/701
# Batch 686: Model has outputted results.
# Image 1 in batch 686: Object counts - {'car': 3, 'bus': 0, 'person': 2, 'truck': 0}
# Image 2 in batch 686: Object counts - {'car': 1, 'bus': 0, 'person': 3, 'truck': 0}
# Image 3 in batch 686: Object counts - {'car': 4, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 686: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 1}
# Image 5 in batch 686: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 686: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 7 in batch 686: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 8 in batch 686: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 686.
# 2021-05-07 17:15:13
# 2021-05-07 17:17:08
# 2021-05-07 17:19:04
# 2021-05-07 17:21:02
# 2021-05-07 17:22:57
# 2021-05-07 17:24:52
# 2021-05-07 17:26:42
# 2021-05-07 17:28:31
# Processing batch 687/701
# Batch 687: Model has outputted results.
# Image 1 in batch 687: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 687: Object counts - {'car': 2, 'bus': 1, 'person': 0, 'truck': 0}
# Image 3 in batch 687: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 687: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 687: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 687: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 687: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Image 8 in batch 687: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 687.
# 2021-05-07 17:30:17
# 2021-05-07 17:32:05
# 2021-05-07 17:33:55
# 2021-05-07 17:35:44
# 2021-05-07 17:37:35
# 2021-05-07 17:39:26
# 2021-05-07 17:41:17
# 2021-05-07 17:43:13
# Processing batch 688/701
# Batch 688: Model has outputted results.
# Image 1 in batch 688: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 688: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 688: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 688: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 688: Object counts - {'car': 3, 'bus': 0, 'person': 1, 'truck': 1}
# Image 6 in batch 688: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 688: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 688: Object counts - {'car': 1, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 688.
# 2021-05-07 17:45:11
# 2021-05-07 17:47:05
# 2021-05-07 17:48:56
# 2021-05-07 17:50:46
# 2021-05-07 17:52:36
# 2021-05-07 17:54:28
# 2021-05-07 17:56:17
# 2021-05-07 17:58:06
# Processing batch 689/701
# Batch 689: Model has outputted results.
# Image 1 in batch 689: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 689: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 3 in batch 689: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 689: Object counts - {'car': 5, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 689: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 6 in batch 689: Object counts - {'car': 6, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 689: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Image 8 in batch 689: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 689.
# 2021-05-07 17:59:55
# 2021-05-07 18:01:45
# 2021-05-07 18:03:38
# 2021-05-07 18:05:34
# 2021-05-07 18:07:32
# 2021-05-07 18:09:29
# 2021-05-07 18:11:25
# 2021-05-07 18:13:20
# Processing batch 690/701
# Batch 690: Model has outputted results.
# Image 1 in batch 690: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 690: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 690: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 690: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Image 5 in batch 690: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 690: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 690: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 1}
# Image 8 in batch 690: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 690.
# 2021-05-07 18:15:14
# 2021-05-07 18:17:06
# 2021-05-07 18:18:53
# 2021-05-07 18:20:42
# 2021-05-07 18:22:33
# 2021-05-07 18:24:24
# 2021-05-07 18:26:14
# 2021-05-07 18:28:02
# Processing batch 691/701
# Batch 691: Model has outputted results.
# Image 1 in batch 691: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Image 2 in batch 691: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 691: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 691: Object counts - {'car': 2, 'bus': 0, 'person': 1, 'truck': 0}
# Image 5 in batch 691: Object counts - {'car': 4, 'bus': 0, 'person': 1, 'truck': 0}
# Image 6 in batch 691: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 691: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 691: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 691.
# 2021-05-07 18:29:53
# 2021-05-07 18:31:42
# 2021-05-07 18:33:39
# 2021-05-07 18:35:28
# 2021-05-07 18:37:16
# 2021-05-07 18:39:04
# 2021-05-07 18:40:51
# 2021-05-07 18:42:34
# Processing batch 692/701
# Batch 692: Model has outputted results.
# Image 1 in batch 692: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 692: Object counts - {'car': 1, 'bus': 1, 'person': 2, 'truck': 0}
# Image 3 in batch 692: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 692: Object counts - {'car': 4, 'bus': 0, 'person': 2, 'truck': 0}
# Image 5 in batch 692: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 692: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 692: Object counts - {'car': 2, 'bus': 1, 'person': 1, 'truck': 0}
# Image 8 in batch 692: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 1}
# Completed processing batch 692.
# 2021-05-07 18:44:20
# 2021-05-07 18:46:05
# 2021-05-07 18:47:50
# 2021-05-07 18:49:32
# 2021-05-07 18:51:17
# 2021-05-07 18:53:02
# 2021-05-07 18:54:46
# 2021-05-07 18:56:29
# Processing batch 693/701
# Batch 693: Model has outputted results.
# Image 1 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 2 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 693: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 7 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 693: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Completed processing batch 693.
# 2021-05-07 18:58:12
# 2021-05-07 18:59:55
# 2021-05-07 19:01:39
# 2021-05-07 19:03:22
# 2021-05-07 19:05:05
# 2021-05-07 19:06:48
# 2021-05-07 19:08:32
# 2021-05-07 19:10:14
# Processing batch 694/701
# Batch 694: Model has outputted results.
# Image 1 in batch 694: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 694: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 694: Object counts - {'car': 0, 'bus': 1, 'person': 2, 'truck': 0}
# Image 4 in batch 694: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 694: Object counts - {'car': 1, 'bus': 1, 'person': 1, 'truck': 0}
# Image 6 in batch 694: Object counts - {'car': 4, 'bus': 0, 'person': 1, 'truck': 0}
# Image 7 in batch 694: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 8 in batch 694: Object counts - {'car': 0, 'bus': 1, 'person': 0, 'truck': 0}
# Completed processing batch 694.
# 2021-05-07 19:11:57
# 2021-05-07 19:13:40
# 2021-05-07 19:15:22
# 2021-05-07 19:17:04
# 2021-05-07 19:18:45
# 2021-05-07 19:20:26
# 2021-05-07 19:22:08
# 2021-05-07 19:23:50
# Processing batch 695/701
# Batch 695: Model has outputted results.
# Image 1 in batch 695: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 695: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 695: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 695: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 695: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 695: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 695: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 8 in batch 695: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Completed processing batch 695.
# 2021-05-07 19:25:32
# 2021-05-07 19:27:14
# 2021-05-07 19:28:57
# 2021-05-07 19:30:39
# 2021-05-07 19:32:21
# 2021-05-07 19:34:03
# 2021-05-07 19:35:49
# 2021-05-07 19:37:35
# Processing batch 696/701
# Batch 696: Model has outputted results.
# Image 1 in batch 696: Object counts - {'car': 2, 'bus': 1, 'person': 0, 'truck': 0}
# Image 2 in batch 696: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 696: Object counts - {'car': 3, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 696: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 696: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 696: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 696: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 696: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 1}
# Completed processing batch 696.
# 2021-05-07 19:39:20
# 2021-05-07 19:41:03
# 2021-05-07 19:42:47
# 2021-05-07 19:44:29
# 2021-05-07 19:46:12
# 2021-05-07 19:47:54
# 2021-05-07 19:49:36
# 2021-05-07 19:51:19
# Processing batch 697/701
# Batch 697: Model has outputted results.
# Image 1 in batch 697: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 697: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 697: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 0}
# Image 4 in batch 697: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 5 in batch 697: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 697: Object counts - {'car': 1, 'bus': 0, 'person': 1, 'truck': 0}
# Image 7 in batch 697: Object counts - {'car': 0, 'bus': 2, 'person': 2, 'truck': 0}
# Image 8 in batch 697: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Completed processing batch 697.
# 2021-05-07 19:53:03
# 2021-05-07 19:54:47
# 2021-05-07 19:56:31
# 2021-05-07 19:58:17
# 2021-05-07 20:00:03
# 2021-05-07 20:16:38
# 2021-05-07 20:18:20
# 2021-05-07 20:20:03
# Processing batch 698/701
# Batch 698: Model has outputted results.
# Image 1 in batch 698: Object counts - {'car': 1, 'bus': 0, 'person': 2, 'truck': 0}
# Image 2 in batch 698: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Image 3 in batch 698: Object counts - {'car': 0, 'bus': 0, 'person': 4, 'truck': 0}
# Image 4 in batch 698: Object counts - {'car': 3, 'bus': 0, 'person': 1, 'truck': 0}
# Image 5 in batch 698: Object counts - {'car': 0, 'bus': 0, 'person': 4, 'truck': 0}
# Image 6 in batch 698: Object counts - {'car': 2, 'bus': 0, 'person': 3, 'truck': 0}
# Image 7 in batch 698: Object counts - {'car': 2, 'bus': 0, 'person': 2, 'truck': 0}
# Image 8 in batch 698: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 0}
# Completed processing batch 698.
# 2021-05-07 20:21:46
# 2021-05-07 20:23:28
# 2021-05-07 20:25:09
# 2021-05-07 20:26:51
# 2021-05-07 20:28:31
# 2021-05-07 20:30:12
# 2021-05-07 20:31:53
# 2021-05-07 20:33:34
# Processing batch 699/701
# Batch 699: Model has outputted results.
# Image 1 in batch 699: Object counts - {'car': 2, 'bus': 1, 'person': 0, 'truck': 0}
# Image 2 in batch 699: Object counts - {'car': 2, 'bus': 0, 'person': 1, 'truck': 0}
# Image 3 in batch 699: Object counts - {'car': 0, 'bus': 0, 'person': 2, 'truck': 1}
# Image 4 in batch 699: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 699: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 699: Object counts - {'car': 1, 'bus': 1, 'person': 0, 'truck': 0}
# Image 7 in batch 699: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 699: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 699.
# 2021-05-07 20:35:14
# 2021-05-07 20:36:55
# 2021-05-07 20:38:37
# 2021-05-07 20:40:19
# 2021-05-07 20:42:01
# 2021-05-07 20:43:43
# 2021-05-07 20:45:25
# 2021-05-07 20:47:06
# Processing batch 700/701
# Batch 700: Model has outputted results.
# Image 1 in batch 700: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 700: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 700: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 700: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 700: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 700: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 7 in batch 700: Object counts - {'car': 2, 'bus': 0, 'person': 0, 'truck': 0}
# Image 8 in batch 700: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 700.
# 2021-05-07 20:48:47
# 2021-05-07 20:50:29
# 2021-05-07 20:52:09
# 2021-05-07 20:53:51
# 2021-05-07 20:55:33
# 2021-05-07 20:57:15
# 2021-05-07 20:58:59
# Processing batch 701/701
# Batch 701: Model has outputted results.
# Image 1 in batch 701: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Image 2 in batch 701: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 3 in batch 701: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 4 in batch 701: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 5 in batch 701: Object counts - {'car': 0, 'bus': 0, 'person': 0, 'truck': 0}
# Image 6 in batch 701: Object counts - {'car': 0, 'bus': 0, 'person': 1, 'truck': 1}
# Image 7 in batch 701: Object counts - {'car': 1, 'bus': 0, 'person': 0, 'truck': 0}
# Completed processing batch 701.
# Completed all processing.
# Summary of object counts:
# car: Total count over all images - 3236
# bus: Total count over all images - 470
# person: Total count over all images - 1728
# truck: Total count over all images - 253

# %%
# ensure all hours from 00 to 23 are represented in the data
all_hours = pd.DataFrame({'hour': range(24)})

for category in interested_objects:
    timestamps, counts = zip(*object_counts[category])  # Extract data for the current category
    
    data = {'timestamp': timestamps, 'count': counts}
    df = pd.DataFrame(data)
    
    # convert timestamps to pandas datetime objects and extract date and hour
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df['date'] = df['timestamp'].dt.date
    df['hour'] = df['timestamp'].dt.hour

    # calculate the average count per hour across all dates for the current category
    daily_hourly_counts = df.groupby(['date', 'hour'])['count'].sum().reset_index()
    average_hourly_counts = daily_hourly_counts.groupby('hour')['count'].mean().reset_index()
    
    # merge with all_hours to ensure every hour is represented
    average_hourly_counts = pd.merge(all_hours, average_hourly_counts, on='hour', how='left').fillna(0)

    # plotting as a bar chart for the current category
    plt.figure(figsize=(12, 8))
    bars = plt.bar(average_hourly_counts['hour'], average_hourly_counts['count'], color='skyblue')
    
    plt.xlabel('Hour of Day')
    plt.ylabel(f'Average Number of {category.capitalize()}s')
    plt.title(f'Average {category.capitalize()} Counts by Hour For One Week')
    plt.xticks(range(24), [f"{hour:02d}:00" for hour in range(24)], rotation=45)
    plt.grid(axis='y')  # Display horizontal grid lines for better readability

    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2.0, yval, "{:.1f}".format(yval), va='bottom', ha='center')
    print(average_hourly_counts)
    
    plt.show()
# Out:
#     hour      count
# 0      0   6.857143
# 1      1   2.857143
# 2      2   1.285714
# 3      3   1.571429
# 4      4   0.857143
# 5      5   1.000000
# 6      6   0.285714
# 7      7   7.857143
# 8      8  21.000000
# 9      9  16.714286
# 10    10  27.285714
# 11    11  23.857143
# 12    12  32.428571
# 13    13  40.714286
# 14    14  39.142857
# 15    15  46.285714
# 16    16  39.142857
# 17    17  34.714286
# 18    18  37.285714
# 19    19  29.142857
# 20    20  19.571429
# 21    21  16.166667
# 22    22  13.166667
# 23    23   8.500000
#     hour     count
# 0      0  1.285714
# 1      1  0.857143
# 2      2  1.142857
# 3      3  0.142857
# 4      4  0.000000
# 5      5  0.285714
# 6      6  1.142857
# 7      7  2.571429
# 8      8  3.857143
# 9      9  4.714286
# 10    10  4.571429
# 11    11  4.428571
# 12    12  4.000000
# 13    13  4.857143
# 14    14  5.285714
# 15    15  5.857143
# 16    16  3.000000
# 17    17  4.142857
# 18    18  3.857143
# 19    19  3.428571
# 20    20  3.142857
# 21    21  2.333333
# 22    22  1.500000
# 23    23  1.500000
#     hour      count
# 0      0   2.428571
# 1      1   1.428571
# 2      2   1.714286
# 3      3   1.000000
# 4      4   0.857143
# 5      5   0.428571
# 6      6   0.285714
# 7      7   1.428571
# 8      8   5.428571
# 9      9   8.571429
# 10    10   9.428571
# 11    11  14.285714
# 12    12  14.285714
# 13    13  26.000000
# 14    14  22.857143
# 15    15  23.428571
# 16    16  27.571429
# 17    17  17.571429
# 18    18  21.571429
# 19    19  17.142857
# 20    20  13.571429
# 21    21  11.333333
# 22    22   3.166667
# 23    23   3.666667
#     hour     count
# 0      0  0.000000
# 1      1  0.000000
# 2      2  0.000000
# 3      3  0.285714
# 4      4  0.000000
# 5      5  0.142857
# 6      6  0.000000
# 7      7  2.000000
# 8      8  3.000000
# 9      9  4.285714
# 10    10  2.285714
# 11    11  3.000000
# 12    12  2.142857
# 13    13  3.142857
# 14    14  2.857143
# 15    15  3.285714
# 16    16  2.142857
# 17    17  2.571429
# 18    18  2.000000
# 19    19  1.285714
# 20    20  1.000000
# 21    21  0.666667
# 22    22  0.166667
# 23    23  0.000000

# %%
for category in interested_objects:
    # Extract timestamps and counts for the current category
    timestamps, counts = zip(*object_counts[category])

    # Create a DataFrame for the current category
    df = pd.DataFrame({'timestamp': timestamps, 'count': counts})
    
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    
    # Extract date and hour from the timestamp
    df['date'] = df['timestamp'].dt.date
    df['hour'] = df['timestamp'].dt.hour

    # Create a pivot table for the heatmap
    heatmap_data = df.pivot_table(values='count', index='date', columns='hour', aggfunc='sum')

    # Plotting the heatmap
    plt.figure(figsize=(14, 10))
    sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt=".0f", linewidths=.5)
    plt.title(f'Hourly {category.capitalize()} Traffic Heatmap by Date')
    plt.xlabel('Hour of Day')
    plt.ylabel('Date')
    plt.tight_layout() 
    plt.show()

# %%
def draw_boxes_with_borderline(image, boxes, labels, scores, threshold=0.5, borderline_y=0):

    image = np.array(to_pil_image(image)) if not isinstance(image, np.ndarray) else image
    if image.dtype != np.uint8:
        image = (image * 255).astype(np.uint8)
    
    # Draw the borderline
    cv2.line(image, (0, borderline_y), (image.shape[1], borderline_y), (255, 0, 0), 3)  # Blue line
    
    for box, label, score in zip(boxes, labels, scores):
        if score > threshold:
            x1, y1, x2, y2 = box.int().tolist()
            
            # Check if the object is below or intersects the borderline (adjust logic as needed)
            if y1 > borderline_y or y2 > borderline_y:
                label_name = COCO_INSTANCE_CATEGORY_NAMES[label.item()]
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(image, f'{label_name}: {score:.2f}', (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)
    
    plt.figure(figsize=(12, 8))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()


# Example usage for the first image in a batch
image, _ = dataset[0] 
outputs = model([image.to(device)])
draw_boxes_with_borderline(image, outputs[0]['boxes'], outputs[0]['labels'], outputs[0]['scores'], threshold=0.0)
